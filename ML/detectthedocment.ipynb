# %%
# keras_server.py 

# Python program to expose a ML model as flask REST API 
import tensorflow as tf 
# import the necessary modules 
import numpy as np 
import flask 
import io 
# import the necessary packages
from keras.models import load_model
#from pyimagesearch import config
import imutils
import cv2
# Create Flask application and initialize Keras model 
app = flask.Flask(__name__) 
model1 = None

# Function to Load the model 
def load_model1(): 
    
    # global variables, to be used in another function 
    global model1
    model1 = load_model('/root/Python code/KYC Detect/mdl_wts_1.hdf5') 
    global graph 
    graph = tf.get_default_graph() 
# Every ML/DL model has a specific format 
# of taking input. Before we can predict on 
# the input image, we first need to preprocess it. 
def prepare_image(image, target): 
	if image.mode != "RGB": 
		image = image.convert("RGB") 
	
	# Resize the image to the target dimensions 
	image = image.resize(target) 
	
	# PIL Image to Numpy array 
	image = img_to_array(image) 
	
	# Expand the shape of an array, 
	# as required by the Model 
	image = np.expand_dims(image, axis = 0) 
	
	# preprocess_input function is meant to 
	# adequate your image to the format the model requires 
	image = imagenet_utils.preprocess_input(image) 

	# return the processed image 
	return image 

# Now, we can predict the results. 
@app.route("/", methods =["POST"]) 
def predict(): 
    data = {} # dictionary to store result 
    data["success"] = False

    # Check if image was properly sent to our endpoint 
    if flask.request.method == "POST": 
        if flask.request.files.get("image"): 
            image = flask.request.files["image"].read() 
            print('1',type(image))
            
            nparr = np.fromstring(image, np.uint8)
            print('2',nparr,type(nparr))
            image = cv2.imdecode(nparr, flags=1) # cv2.IMREAD_COLOR
#             image = Image.open(io.BytesIO(image)) 
            print('3',type(image),image)
#             image = image.convert("RGB")
#             print('3',type(image))
#             output = image.copy()
#             output = imutils.resize(output, width=400)
#             # our model was trained on RGB ordered images but OpenCV represents
            # images in BGR order, so swap the channels, and then resize to
            # 224x224 (the input dimensions for VGG16)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (224, 224))
            print('final image',image)
            # convert the image to a floating point data type and perform mean
            # subtraction
            # load the trained model from disk
            CLASSES = ["aadhar","DL","pan"]
            print("[INFO] loading model...",model1)
            # pass the image through the network to obtain our predictions
            with graph.as_default(): 
				#preds = model.predict(image) 
                preds = model1.predict(np.expand_dims(image, axis=0))[0]
            i = np.argmax(preds)
            label = CLASSES[i]
            # draw the prediction on the output image
            text = "{}: {:.2f}%".format(label, preds[i] * 100)
            #cv2.putText(output, text, (3, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0, 255, 0), 2)


            if (preds[i]*100)>90:
                print(label, preds[i]*100)
            else:
                print('Other')
            print(text)
            data["success"] = True

	# return JSON response 
    return flask.jsonify(data) 
    



if __name__ == "__main__": 
    print(("* Loading Keras model and Flask starting server...please wait until server has fully started")) 
    load_model1() 
    print('Model loaded')
    app.run(host='0.0.0.0')
# Out:
# * Loading Keras model and Flask starting server...please wait until server has fully started
# Model loaded
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 27.6.224.104 - - [03/Mar/2020 07:06:46] "GET / HTTP/1.1" 405 -

# %%
# keras_server.py 

# Python program to expose a ML model as flask REST API 
import tensorflow as tf 
# import the necessary modules 
import numpy as np 
import flask 
import io 
from flask import render_template
# import the necessary packages
from keras.models import load_model
#from pyimagesearch import config
import imutils
import cv2
import base64
import PIL
# Create Flask application and initialize Keras model 
app = flask.Flask(__name__) 
model1 = None

# Function to Load the model 
def load_model1(): 
    
    # global variables, to be used in another function 
    global model1
    model1 = load_model('/root/Python code/KYC Detect/mdl_wts_1.hdf5') 
    global graph 
    graph = tf.get_default_graph() 
# Every ML/DL model has a specific format 
# of taking input. Before we can predict on 
# the input image, we first need to preprocess it. 
def prepare_image(image, target): 
	if image.mode != "RGB": 
		image = image.convert("RGB") 
	
	# Resize the image to the target dimensions 
	image = image.resize(target) 
	
	# PIL Image to Numpy array 
	image = img_to_array(image) 
	
	# Expand the shape of an array, 
	# as required by the Model 
	image = np.expand_dims(image, axis = 0) 
	
	# preprocess_input function is meant to 
	# adequate your image to the format the model requires 
	image = imagenet_utils.preprocess_input(image) 

	# return the processed image 
	return image 

# Now, we can predict the results. 
@app.route("/prediction", methods =["POST"]) 
def predict(): 
    data = {} # dictionary to store result 
    data["success"] = False

    # Check if image was properly sent to our endpoint 
    if flask.request.method == "POST": 
        if flask.request.files.get("image"): 
            image = flask.request.files["image"]
            print('1',type(image))
            
            image.save(image.filename);
            image_filename = image.filename;
            with open(image_filename, "rb") as im:
                b = base64.b64encode(im.read())
                image = b
            nparr = np.fromstring(image, np.uint8)
            print('2',nparr,type(nparr))
            image1 = cv2.imdecode(nparr, flags=1) # cv2.IMREAD_COLOR
#             image = Image.open(io.BytesIO(image)) 
            print('3',type(image1),image1)
#           
#             image = image.convert("RGB")
#             print('3',type(image))
#             output = image.copy()
#             output = imutils.resize(output, width=400)
#             # our model was trained on RGB ordered images but OpenCV represents
            # images in BGR order, so swap the channels, and then resize to
            # 224x224 (the input dimensions for VGG16)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (224, 224))
            print('final image',image)
            # convert the image to a floating point data type and perform mean
            # subtraction
            # load the trained model from disk
            CLASSES = ["aadhar","DL","pan"]
            print("[INFO] loading model...",model1)
            # pass the image through the network to obtain our predictions
            with graph.as_default(): 
				#preds = model.predict(image) 
                preds = model1.predict(np.expand_dims(image, axis=0))[0]
            i = np.argmax(preds)
            label = CLASSES[i]
            # draw the prediction on the output image
            text = "{}: {:.2f}%".format(label, preds[i] * 100)
            #cv2.putText(output, text, (3, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0, 255, 0), 2)


            if (preds[i]*100)>90:
                print(label, preds[i]*100)
            else:
                print('Other')
            print(text)
            data["success"] = True

	# return JSON response 
    dict_data = {}
    dict_data['data'] = flask.jsonify(data) 
    dict_data['label'] = label
    dict_data['image_name'] = image_filename;
    return rennder_template('display.html', dict_data = dict_data);





if __name__ == "__main__": 
    print(("* Loading Keras model and Flask starting server...please wait until server has fully started")) 
    load_model1() 
    print('Model loaded')
    app.run(host='0.0.0.0')
# Out:
# * Loading Keras model and Flask starting server...please wait until server has fully started
# Model loaded
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 27.6.224.104 - - [03/Mar/2020 06:13:19] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03')
# 27.6.224.104 - - [03/Mar/2020 06:13:19] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03|\x04I¹Hz\xad\x02\x83yÍýÍ!\x11/Ak¥Õ\x07÷EOSÑ\x1b~>\x89õ4 ]ì±\x8cr½ww-çS=9\x83H?°\x1f£\x9b\x0c\x8a3O\x92Ý>\xadÅ°tÀ\x00"ÚÚ\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# 27.6.224.104 - - [03/Mar/2020 06:13:19] "ü" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:19] "ü|I¹Hz­yÍýÍ!/Ak¥Õ÷EOSÑ~>õ4 ]ì±r½ww-çS=9H?°£3OÝ>­Å°tÀ"ÚÚÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:20] code 400, message Bad HTTP/0.9 request type ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03\x93\x10÷ç(Ö½<+Ã3\x99Þ')
# 27.6.224.104 - - [03/Mar/2020 06:13:20] "ü÷ç(Ö½<+Ã3Þ	XÛíí" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:21] code 400, message Bad request version ('<Qj\x9a¾Tí¾ë&\x7féý¼\x93\x00¾ý\x12Q½ô\x9f»\x13íÌ\xad¿s\'\x00"\x8a\x8a\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# 27.6.224.104 - - [03/Mar/2020 06:13:21] "ü§Éü§HPN½^L,ç1@OjïÊ7DL 	<Qj¾Tí¾ë&éý¼¾ýQ½ô»íÌ­¿s'"À+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:21] code 400, message Bad HTTP/0.9 request type ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03\xad=Æ<ö\x00Á\x12&Ù¾,i\x91\x9b;ÏÝÎX\x0fÛJuj\x18\x95)xT´¨')
# 27.6.224.104 - - [03/Mar/2020 06:13:21] "ü­=Æ<öÁ&Ù¾,i;ÏÝÎXÛJuj)xT´¨ ÉRÕ%Ä[ØrC" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:34] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03\x83ò\\U®\x8bÑ¶\x01à\x96\x98f\x8d9ýr=\x06-¶_[Øí\x96\x9e\\´\x96ë\x83 Åá|\x15\x93®Ê£d\x1bd\x1eªßs\t\x9a5Á\'¢\x1d÷m\x07\x15¹\x8c¡%«è\x00"úú\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# 27.6.224.104 - - [03/Mar/2020 06:13:34] "üò\U®Ñ¶àf9ýr=-¶_[Øí\´ë Åá|®Ê£ddªßs	5Á'¢÷m¹¡%«è"úúÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:34] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03¹nF«')
# 27.6.224.104 - - [03/Mar/2020 06:13:34] "ü¹nF«" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:34] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03ÈzÒjv\x95*Kâ\x9d¹\x92O\x8dBôéy³ðÎ`\x0bô\x90Â\x91°Ð\x95×ö ö5¸CÉ¬fT\x91Þ`ýÕ\x9d\x89;)\x0fÉC\x0ciÅ>spN\x94\x199Òæ\x00"**\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# 27.6.224.104 - - [03/Mar/2020 06:13:34] "üÈzÒjv*Kâ¹OBôéy³ðÎ`ôÂ°Ð×ö ö5¸CÉ¬fTÞ`ýÕ;)ÉCiÅ>spN9Òæ"**À+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:13:34] code 400, message Bad request version ('_À\x18åtã\x96È,q°=Æ\x06Í\x10\x05£ÂU\x95\x82u?4QVÛq}÷\x00"ÚÚ\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# `CxOB¶Úf¨{ÔLZlX{ _ÀåtãÈ,q°=ÆÍ£ÂUu?4QVÛq}÷"ÚÚÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:14:16] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03®0S$|¨\x96·Ñ·æâ\x9a×h Ä,\x15}ÆÎ7\x8dÅHtr\x90N\x82\x15 \x9a\rvr¤N,Z£Æ¯0\x80ú¦¬xk>%ñå¸ç®Lü8úBWM\x00"ÚÚ\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# vr¤N,Z£Æ¯0ú¦¬xk>%ñå¸ç®Lü8úBWM"ÚÚÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:14:16] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03;¡x\x87Ô\x00[öUlè\x86)Rbaç\x1d6\x1cÏ\x13\x8d´¤÷æ@Ï·\x17\x8c \x99s\x9c\x85]Ò\x93\x95\x05\x81©/HºÝ\x02ÂØ\x1e.óäÕS|\x94û\x1cÉ[wÞ\x00"zz\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# 27.6.224.104 - - [03/Mar/2020 06:14:16] "ü;¡xÔ[öUlè)Rbaç6Ï´¤÷æ@Ï· s]Ò©/HºÝÂØ.óäÕS|ûÉ[wÞ"zzÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:14:16] code 400, message Bad HTTP/0.9 request type ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03$\x18K\x7f¯^¥6\x16Ø×ÂÀ\x8fYl|Wð÷\x86v¥I-\x9cMAðÏcï')
# 27.6.224.104 - - [03/Mar/2020 06:14:16] "ü$K¯^¥6Ø×ÂÀYl|Wð÷v¥I-MAðÏcï F¯!ÚÖZ$LBP4KÐì¬ðë>Y~ùìæU«GqØ5à"zzÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:14:16] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03z¯Ô\x1eqþèã$\x93Ë¸ôÍêÓe\x11O\x0e\x8bv½\x19·ByV%õo\x9d õ®\x06øøÇÛ\x03\x1bû\x84<Óû\t`o~&z\x06@q\x9d\x8e|\x83\x1dñÜ0\xa0\x00"zz\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# 27.6.224.104 - - [03/Mar/2020 06:14:16] code 400, message Bad request syntax ('\x16\x03\x01\x02\x00\x01\x00\x01ü\x03\x03i÷V"6\x1b\x81u\x08@aF¬ösÌîz´×\x9c7èÿ\x1f\x1b\x86àø\x15"n Ãimé¦áó¥¥\x03z\'e\tÁvªùã¶íÀÑ¬zóÇ\x10éÆÀO\x00"úú\x13\x01\x13\x02\x13\x03À+À/À,À0Ì©Ì¨À\x13À\x14\x00\x9c\x00\x9d\x00/\x005\x00')
# 27.6.224.104 - - [03/Mar/2020 06:14:16] "üi÷V"6@aF¬ösÌîz´×7èÿàø"n Ãimé¦áó¥¥z'e	Ávªùã¶íÀÑ¬zóÇéÆÀO"úúÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -
# 27.6.224.104 - - [03/Mar/2020 06:14:16] "üz¯Ôqþèã$Ë¸ôÍêÓeOv½·ByV%õo õ®øøÇÛû<Óû	`o~&z@q|ñÜ0 "zzÀ+À/À,À0Ì©Ì¨ÀÀ/5" HTTPStatus.BAD_REQUEST -

# %%
# keras_server.py 

# Python program to expose a ML model as flask REST API 
import tensorflow as tf 
# import the necessary modules 
import numpy as np 
import flask 
import io 
from flask import render_template
# import the necessary packages
from keras.models import load_model
#from pyimagesearch import config
import imutils
import cv2
# Create Flask application and initialize Keras model 
app = flask.Flask(__name__) 
model1 = None

# Function to Load the model 
def load_model1(): 
    
    # global variables, to be used in another function 
    global model1
    model1 = load_model('/root/Python code/KYC Detect/mdl_wts_1.hdf5') 
    global graph 
    graph = tf.get_default_graph() 
# Every ML/DL model has a specific format 
# of taking input. Before we can predict on 
# the input image, we first need to preprocess it. 
def prepare_image(image, target): 
	if image.mode != "RGB": 
		image = image.convert("RGB") 
	
	# Resize the image to the target dimensions 
	image = image.resize(target) 
	
	# PIL Image to Numpy array 
	image = img_to_array(image) 
	
	# Expand the shape of an array, 
	# as required by the Model 
	image = np.expand_dims(image, axis = 0) 
	
	# preprocess_input function is meant to 
	# adequate your image to the format the model requires 
	image = imagenet_utils.preprocess_input(image) 

	# return the processed image 
	return image 
@app.route("/")
def login1():
      return render_template('index.html')

# Now, we can predict the results. 
@app.route("/prediction", methods =["GET","POST"]) 
def predict(): 
    data = {} # dictionary to store result 
    data["success"] = False

    # Check if image was properly sent to our endpoint 
    if flask.request.method == "POST": 
        if flask.request.files.get("image"): 
            image = flask.request.files["image"].read() 
            print('1',type(image))
            
            nparr = np.fromstring(image, np.uint8)
            print('2',nparr,type(nparr))
            image = cv2.imdecode(nparr, flags=1) # cv2.IMREAD_COLOR
#             image = Image.open(io.BytesIO(image)) 
            print('3',type(image),image)
#             image = image.convert("RGB")
#             print('3',type(image))
#             output = image.copy()
#             output = imutils.resize(output, width=400)
#             # our model was trained on RGB ordered images but OpenCV represents
            # images in BGR order, so swap the channels, and then resize to
            # 224x224 (the input dimensions for VGG16)
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (224, 224))
            print('final image',image)
            # convert the image to a floating point data type and perform mean
            # subtraction
            # load the trained model from disk
            CLASSES = ["aadhar","DL","pan"]
            print("[INFO] loading model...",model1)
            # pass the image through the network to obtain our predictions
            with graph.as_default(): 
				#preds = model.predict(image) 
                preds = model1.predict(np.expand_dims(image, axis=0))[0]
            i = np.argmax(preds)
            label = CLASSES[i]
            # draw the prediction on the output image
            text = "{}: {:.2f}%".format(label, preds[i] * 100)
            #cv2.putText(output, text, (3, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0, 255, 0), 2)


            if (preds[i]*100)>90:
                print(label, preds[i]*100)
            else:
                print('Other')
            print(text)
            data["success"] = True
    dict_data = {}
    dict_data['preds'] = preds[i]*100;
    dict_data['data'] = flask.jsonify(data) 
    dict_data['label'] = label
	# return JSON response 
    return render_template('display.html',dict_data=dict_data) 
    



if __name__ == "__main__": 
    print(("* Loading Keras model and Flask starting server...please wait until server has fully started")) 
    load_model1() 
    print('Model loaded')
    app.run(host='0.0.0.0')
# Out:
# Using TensorFlow backend.
# * Loading Keras model and Flask starting server...please wait until server has fully started
# Model loaded
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://0.0.0.0:5000/ (Press CTRL+C to quit)
# 27.6.224.104 - - [03/Mar/2020 08:52:06] "GET / HTTP/1.1" 200 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /fonts/font-awesome-4.7.0/css/font-awesome.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/animate/animate.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /fonts/Linearicons-Free-v1.0.0/icon-font.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/css-hamburgers/hamburgers.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/animsition/css/animsition.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/select2/select2.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/daterangepicker/daterangepicker.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /css/main.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /css/util.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/animsition/js/animsition.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/jquery/jquery-3.2.1.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/bootstrap/js/popper.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/bootstrap/js/bootstrap.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /images/logo.png HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/select2/select2.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /images/T.jpg HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/daterangepicker/moment.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/daterangepicker/daterangepicker.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /vendor/countdowntime/countdowntime.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:07] "GET /js/main.js HTTP/1.1" 404 -
# 1 <class 'bytes'>
# 2 [137  80  78 ...  66  96 130] <class 'numpy.ndarray'>
# 3 <class 'numpy.ndarray'> [[[189 194 185]
#   [178 181 172]
#   [163 163 157]
#   ...
#   [252 232 197]
#   [255 247 216]
#   [255 255 233]]
#
#  [[180 183 174]
#   [161 164 155]
#   [147 145 137]
#   ...
#   [227 208 171]
#   [243 224 191]
#   [255 244 212]]
#
#  [[148 149 139]
#   [148 147 137]
#   [151 149 139]
#   ...
#   [197 177 136]
#   [209 190 153]
#   [224 205 170]]
#
#  ...
#
#  [[194 177 186]
#   [201 184 193]
#   [211 192 201]
#   ...
#   [239 206 160]
#   [239 208 163]
#   [242 210 167]]
#
#  [[226 220 225]
#   [202 195 200]
#   [198 188 194]
#   ...
#   [223 197 160]
#   [216 191 157]
#   [247 223 195]]
#
#  [[231 230 232]
#   [205 204 206]
#   [200 195 197]
#   ...
#   [238 216 181]
#   [230 209 182]
#   [255 240 219]]]
# final image [[[187 192 183]
#   [172 174 166]
#   [157 154 149]
#   ...
#   [223 203 166]
#   [254 241 208]
#   [255 254 231]]
#
#  [[181 184 175]
#   [161 162 153]
#   [151 148 142]
#   ...
#   [219 199 160]
#   [242 225 191]
#   [254 245 216]]
#
#  [[163 165 156]
#   [152 152 143]
#   [154 150 143]
#   ...
#   [214 192 152]
#   [221 201 165]
#   [238 223 189]]
#
#  ...
#
#  [[209 198 205]
#   [203 190 197]
#   [208 193 200]
#   ...
#   [235 206 162]
#   [229 200 160]
#   [242 214 178]]
#
#  [[224 220 224]
#   [201 195 199]
#   [203 193 198]
#   ...
#   [234 209 168]
#   [223 199 165]
#   [246 224 197]]
#
#  [[227 226 228]
#   [203 200 202]
#   [203 196 199]
#   ...
#   [236 214 174]
#   [233 212 181]
#   [252 236 214]]]
# [INFO] loading model... <keras.engine.training.Model object at 0x7fce69d267b8>
# /root/anaconda3/envs/myenv/lib/python3.6/site-packages/ipykernel_launcher.py:66: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
# 27.6.224.104 - - [03/Mar/2020 08:52:27] "POST /prediction HTTP/1.1" 200 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /fonts/font-awesome-4.7.0/css/font-awesome.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /fonts/Linearicons-Free-v1.0.0/icon-font.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/animate/animate.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/css-hamburgers/hamburgers.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/animsition/css/animsition.min.css HTTP/1.1" 404 -
# pan 98.98900985717773
# pan: 98.99%
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/select2/select2.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/daterangepicker/daterangepicker.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /css/main.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /css/util.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/jquery/jquery-3.2.1.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/animsition/js/animsition.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/bootstrap/js/popper.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/bootstrap/js/bootstrap.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /images/T.jpg HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /images/logo.png HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/select2/select2.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/daterangepicker/moment.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/daterangepicker/daterangepicker.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /vendor/countdowntime/countdowntime.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:52:28] "GET /js/main.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET / HTTP/1.1" 200 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /fonts/font-awesome-4.7.0/css/font-awesome.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /vendor/animate/animate.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /fonts/Linearicons-Free-v1.0.0/icon-font.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /vendor/css-hamburgers/hamburgers.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /vendor/animsition/css/animsition.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /vendor/select2/select2.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /vendor/daterangepicker/daterangepicker.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /css/util.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:25] "GET /css/main.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/jquery/jquery-3.2.1.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/animsition/js/animsition.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/bootstrap/js/popper.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/bootstrap/js/bootstrap.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/daterangepicker/moment.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/select2/select2.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/daterangepicker/daterangepicker.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/countdowntime/countdowntime.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /js/main.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/daterangepicker/moment.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /images/logo.png HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /images/T.jpg HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/daterangepicker/daterangepicker.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /vendor/countdowntime/countdowntime.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /js/main.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 08:58:26] "GET /images/icons/favicon.ico HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:21:02] "GET /vendor/select2/select2.min.js HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:21:02] "GET /favicon.ico HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /vendor/bootstrap/css/bootstrap.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /fonts/font-awesome-4.7.0/css/font-awesome.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /fonts/Linearicons-Free-v1.0.0/icon-font.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /vendor/animate/animate.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /vendor/animsition/css/animsition.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /vendor/css-hamburgers/hamburgers.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /vendor/select2/select2.min.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /vendor/daterangepicker/daterangepicker.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /css/util.css HTTP/1.1" 404 -
# 27.6.224.104 - - [03/Mar/2020 09:23:12] "GET /css/main.css HTTP/1.1" 404 -
